# %% [markdown]
# <a href="https://colab.research.google.com/github/beebadooo/Cartoon-effect-Python/blob/main/Cartoon_image_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# image reading
img = cv2.imread("stones.jpg")

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)
outlines = cv2.adaptiveThreshold(gray, 255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 9, 9)
plt.imshow(outlines)
plt.show()

# %%
# make cartoon of your image
color = cv2.bilateralFilter(img, 9, 250, 250)
plt.imshow(color)
plt.show()

# %%
cartoon = cv2.bitwise_and(color, color, mask=outlines)
plt.imshow(cartoon)
plt.title("The cartoon image is - ")
plt.show()
